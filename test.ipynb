# %%
print("--- Order 表前 3 行 ---")
print(loader.order.head(3))
# Out:
# --- Order 表前 3 行 ---
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print("--- Order 表前 3 行 ---")
# ----> 2 print(loader.order.head(3))
#
# NameError: name 'loader' is not defined

# %%
print(f"T_START: {T_START}")
print(f"T_TARGET: {T_TARGET}")
print("-" * 30)
print(f"Order 表的索引类型: {type(loader.order.index)}")
print(f"Order 表索引前 5 个值: {loader.order.index[:5].tolist()}")
print(f"Order 表是否包含 'time' 列: {'time' in loader.order.columns}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(f"T_START: {T_START}")
#       2 print(f"T_TARGET: {T_TARGET}")
#       3 print("-" * 30)
#
# NameError: name 'T_START' is not defined
